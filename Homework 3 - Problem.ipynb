# %% [markdown]
# ## Problem 1~9. Import nutrition.csv file using pd.read_csv function.

# %% [markdown]
# ## Problem 1. Make all the column names as lower case. This will make your data manipulation processes way easier. Please name your data as 'df'

# %%
###################


###################
print(df.columns)
# Out:
# Index(['food,serving (g/oz)', 'calories', 'calories from fat (g)',
#        'total fat (g)', 'total fat (%dv)', 'sodium (g)', 'sodium (%dv)',
#        'pottasium (%dv)', 'total carbo-hydrate (g)',
#        'total carbo-hydrate (%dv)', 'fiber (g)', 'fiber (%dv)', 'sugars (g)',
#        'protein (g)', 'vitamin a (%dv)', 'vitamin c (%dv)', 'calcium (%dv)',
#        'iron (%dv)', 'type, serving size (g/ounce)'],
#       dtype='object')

# %% [markdown]
# ## Problem 2. You are going to create three new columns called "food name", "serving size" (g), and "food type". Please follow the instructions below.
# ### 2.1 Using "food,serving (g/oz)" column in the nutrition data, create two new columns called "food name" and "serving size (g)". The value of "food name" in each row should be the name of the food presented in "food,serving (g/oz)" column while the value of the "serving size (g)" should be the value of the serving size presented in the same column. For the value "serving size (g)" in each row please do not include 'g' at the end of the number.
# ### 2.2 Using "type, serving size (g/ounce)" column in the original dataset, create a new column called "food type" which is a category variable. The food type can be either 'Vegetables', 'Fruits', or 'Seafood'.

# %%
###################


    
###################

# Please print the following.

print(df['food type'].unique())
print("**************Vegetables**************")
print(df[df['food type']=="Vegetables"][['food name','serving size (g)']])
print("**************Fruits**************")
print(df[df['food type']=="Fruits"][['food name','serving size (g)']])
print("**************Seafood**************")
print(df[df['food type']=="Seafood"][['food name','serving size (g)']])
# Out:
# ['Vegetables' 'Fruits' 'Seafood']
# **************Vegetables**************
#         food name serving size (g)
# 0       Asparagus               93
# 1            Bell              148
# 2        Broccoli              148
# 3          Carrot               78
# 4     Cauliflower               99
# 5          Celery              110
# 6        Cucumber               99
# 7           Green               83
# 8   GreenÊCabbage               84
# 9           Green               25
# 10        Iceberg               89
# 11           Leaf               85
# 12      Mushrooms               84
# 13          Onion              148
# 14         Potato              148
# 15       Radishes               85
# 16  SummerÊSquash               98
# 17          Sweet               90
# 18          Sweet              130
# 19         Tomato              148
# **************Fruits**************
#          food name serving size (g)
# 20           Apple              242
# ...

# %% [markdown]
# ## Problem 3. Based on the dataframe that you created in Problem 2, drop observations based on the missing values of the following columns (if any of values in the 6 columns is missing, drop the observation): 'serving size (g)','total fat (g)','total carbo-hydrate (g)','sugars (g)','protein (g)','food type' ***AND*** change the data type of 'serving size (g)' column as integer.

# %%
###################


###################

# Please print the following.
print(df['serving size (g)'].describe())
# Out:
# count     38.000000
# mean     120.657895
# std       49.075935
# min       25.000000
# 25%       86.000000
# 50%      126.000000
# 75%      148.000000
# max      280.000000
# Name: serving size (g), dtype: float64

# %% [markdown]
# ## Problem 4. Based on the dataframe that you created in Problem 3, create two columns based on the instructions below.
# ### (1) suger percentage = sugar (g) / serving size (g)
# ### (2) calories per gram = calories / serving size (g)
# ### Based on two formulas given, create new columns called "sugar percentage" and "calories per gram".
# ### ***Make sure to round off to two decimal places***

# %%
###################



###################

print(df['sugar percentage'].describe())
print(df['calories per gram'].describe())
# Out:
# count    38.000000
# mean      0.051842
# std       0.040991
# min       0.000000
# 25%       0.020000
# 50%       0.045000
# 75%       0.080000
# max       0.160000
# Name: sugar percentage, dtype: float64
# count    38.000000
# mean      0.419211
# std       0.301020
# min       0.100000
# 25%       0.240000
# 50%       0.355000
# 75%       0.505000
# max       1.670000
# Name: calories per gram, dtype: float64

# %% [markdown]
# ## Problem 5. Based on the dataframe that you created in Problem 4,
# ### (1) print the average of sugars (g) groupped by the type of the food (Fruits or Vegitables)
# ### (2) print the average of sugar percentage groupped by the type of the food (Fruits or Vegitables)
# ### (3) print the average of calories per gram groupped by the type of the food (Fruits or Vegitables)

# %%
###################


###################

# expected outcome will not be provided
# Out:
# food type
# Fruits        12.166667
# Vegetables     2.800000
# Name: sugars (g), dtype: float64
# food type
# Fruits        0.079444
# Vegetables    0.027000
# Name: sugar percentage, dtype: float64
# food type
# Fruits        0.533333
# Vegetables    0.316500
# Name: calories per gram, dtype: float64

# %% [markdown]
# ## Problem 6. Based on the dataframe that you created in Problem 5, keep the following columns and drop the rest.
# * food name
# * food type
# * calories per gram
# * vitamin a (%dv)
# * vitamin c (%dv)
# * calcium (%dv)
# * sugar percentage

# %%
###################


###################
df
# Out:
#          food name   food type  calories per gram  vitamin a (%dv)  \
# 0        Asparagus  Vegetables               0.22               10
# 1             Bell  Vegetables               0.17                4
# 2         Broccoli  Vegetables               0.30                6
# 3           Carrot  Vegetables               0.38              110
# 4      Cauliflower  Vegetables               0.25                0
# 5           Celery  Vegetables               0.14               10
# 6         Cucumber  Vegetables               0.10                4
# 7            Green  Vegetables               0.24                4
# 8    GreenÊCabbage  Vegetables               0.30                0
# 9            Green  Vegetables               0.40                2
# 10         Iceberg  Vegetables               0.11                6
# 11            Leaf  Vegetables               0.18              130
# 12       Mushrooms  Vegetables               0.24                0
# ...

# %% [markdown]
# ## Problem 7. Based on the dataframe that you created in Problem 6, sort the vlues of sugar percentage in descending order and by food type.

# %%
###################



###################
# Out:
#      food type       food name  sugar percentage
# 25      Fruits          Grapes              0.16
# 22      Fruits          Banana              0.15
# 35      Fruits           Plums              0.11
# 20      Fruits           Apple              0.10
# 33      Fruits            Pear              0.10
# 27      Fruits       Kiwifruit              0.09
# 31      Fruits          Orange              0.09
# 32      Fruits           Peach              0.09
# 23      Fruits      Cantaloupe              0.08
# 26      Fruits  HoneydewÊMelon              0.08
# 30      Fruits       Nectarine              0.08
# 38      Fruits       Tangerine              0.08
# 24      Fruits      Grapefruit              0.07
# 39      Fruits      Watermelon              0.07
# 36      Fruits    Strawberries              0.05
# 28      Fruits           Lemon              0.03
# 21      Fruits         Avocado              0.00
# 29      Fruits            Lime              0.00
# ...

# %% [markdown]
# ## Problem 8. Based on the dataframe that you created in Problem 6, visualize as following. (Please refer to the two graphs give below)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

###################

# set the height parameter as 5.5




###################

# %% [markdown]
# ## Problem 8. Look at the second graph presented in the expected outcome for Problem 7. Remove one outlier plotted in the top left corner of the graph. Then, repeat the codes that you wrote for problem 8.

# %%
###################


###################
